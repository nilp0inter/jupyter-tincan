# %%
import numpy as np
import pandas as pd

import classified

# %%
df = classified.get_top_secret_data()
df.iloc[0:5]
# Out:
#     Project Code Name                                              Brief  \
# 0    Apollo Unearthed  Lunar set, Studio 51, Nevada Desert. Shutter S...
# 1  Majestic 12 Guests  Visitor log including Zorg, Chewbacca. RSVP st...
# 2  Operation Atlantis  Coordinates: Undisclosed. Status: Active. Seek...
# 3  Nessie's Itinerary  Daily routine: Splash, Greet, Siesta. Tea Time...
# 4    Sasquatch Sizing  Footwear logistics. Size: Classified. Preferre...
#
#      Clearance Level
# 0              Ultra
# 1  Cosmic Top Secret
# 2          Eyes Only
# 3        Delta Green
# 4             Shadow

# %%
# !tree -n classified_documents/
# Out:
# *stdout*
